# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
#Importing all the required library
import selenium 
import pandas as pd
from selenium import webdriver 
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver= webdriver.Chrome("chromedriver.exe")
# Get the webpage
url="https://www.naukri.com/" 
driver.get(url)

# %%
search_job= driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys("Data Analyst")
search_loc= driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")
search_btn=driver.find_element_by_xpath('//button[@class="btn"]')
search_btn.click()

# %%
Job_tit=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

# %%
Job_Title=[]
for i in Job_tit:
    Job_Title.append(i.text)

# %%
job_locn=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

# %%
Job_Location=[]
for i in job_locn:
    Job_Location.append(i.text)

# %%
comp_name= driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

# %%
Company_name=[]
for i in comp_name:
    Company_name.append(i.text)

# %%
exp_required= driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')

# %%
Experience_require= []
for i in exp_required:
    Experience_require.append(i.text)

# %%
len(Experience_require)

# %%
Job_Data= pd.DataFrame({})
Job_Data['Job_Title']=Job_Title
Job_Data['Job_Location']=Job_Location
Job_Data['Company_name']=Company_name
Job_Data['Experience_required']= Experience_require

# %%
Job_Data
# Out:
#                                             Job_Title  \
# 0                                 Senior Data Analyst
# 1    Tcs Hiring For Senior Data Analyst (bfsi domain)
# 2                               Business Data Analyst
# 3                               Business Data Analyst
# 4    Business Data Analyst - Google Data Studio & SQL
# 5                                 Senior Data Analyst
# 6   Tcs Hiring For MDM (master data management) Da...
# 7                   Senior Data Analyst IDAM Services
# 8                       Data Analyst/Sr.Data Engineer
# 9                                 SENIOR DATA ANALYST
# 10                             Executive Data Analyst
# 11                            Senior Data Analyst IN4
# 12      Analyst & Designer - Software - Data Analysis
# 13                                Data Analyst - I/II
# 14  Systems and Data Analyst, Safety and Provisioning
# 15                                       Data Analyst
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, full job-description. You have to scrape first 10 jobs data.

# %%
Driver=webdriver.Chrome("chromedriver.exe")
# Get the webpage
url="https://www.naukri.com/" 
Driver.get(url)

# %%
search_job= Driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys("Data Scientist")
search_loc= Driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore") 

search_btn=Driver.find_element_by_xpath('//button[@class="btn"]')
search_btn.click()

# %%
Job_tit=Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

# %%
Job_title=[]
for i in Job_tit:
    Job_title.append(i.text)

# %%
job_locn=Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

# %%
job_location= []
for i in job_locn:
    job_location.append(i.text)

# %%
comp_name= Driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

# %%
Company_name=[]
for i in comp_name:
    Company_name.append(i.text)

# %%
url= Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

# %%
job_urls=[]
for i in url:
    job_urls.append(i.get_attribute('href'))

# %%
job_description=[]
for i in job_urls:
    Driver.get(i)
    time.sleep(5)
    try:
        job_desc=Driver.find_element_by_xpath('//section[@class="job-desc"]')
        job_description.append(job_desc.text)
    except:
        job_description.append('--')

# %%
Naukri_Data= pd.DataFrame({})
Naukri_Data['Job_Title']=Job_title
Naukri_Data['Job_Location']=job_location
Naukri_Data['Company_name']=Company_name
Naukri_Data['job_description']= job_description
Naukri_Data
# Out:
#                                             Job_Title  \
# 0                                 Senior Data Analyst
# 1    Tcs Hiring For Senior Data Analyst (bfsi domain)
# 2                               Business Data Analyst
# 3                               Business Data Analyst
# 4    Business Data Analyst - Google Data Studio & SQL
# 5                                 Senior Data Analyst
# 6   Tcs Hiring For MDM (master data management) Da...
# 7                   Senior Data Analyst IDAM Services
# 8                       Data Analyst/Sr.Data Engineer
# 9                                 SENIOR DATA ANALYST
# 10                             Executive Data Analyst
# 11                            Senior Data Analyst IN4
# 12      Analyst & Designer - Software - Data Analysis
# 13                                Data Analyst - I/II
# 14  Systems and Data Analyst, Safety and Provisioning
# 15                                       Data Analyst
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
Driver=webdriver.Chrome("chromedriver.exe")

# Get the webpage
url="https://www.naukri.com/" 
Driver.get(url)

# %%
search_job= Driver.find_element_by_id('qsb-keyword-sugg')

search_job.send_keys("Data Scientist")

search_btn=Driver.find_element_by_xpath('//button[@class="btn"]')

search_btn.click()

# %%
filter_btn1=Driver.find_element_by_xpath('//span[@title="3-6 Lakhs"]')
filter_btn1.click()

# %%
filter_btn2=Driver.find_element_by_xpath('//span[@title="Delhi / NCR"]')
filter_btn2.click()

# %%
Job_title3= Driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

# %%
Job_titles3=[]
for i in Job_title3:
    Job_titles3.append(i.text)
Job_titles3=Job_titles3[0:10]

# %%
job_location3= Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

# %%
job_locations3=[]
for i in job_location3[0:10]:
    job_locations3.append(i.text)

# %%
company_name3= Driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

# %%
company_names3= []
for i in company_name3[0:10]:
    company_names3.append(i.text)

# %%
experience_required3= Driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')

# %%
Experience_required3=[]
for i in experience_required3[0:10]:
    Experience_required3.append(i.text)

# %%
NCR_job= pd.DataFrame({})
NCR_job['Job_Title']=Job_titles3
NCR_job['Job_locations']= job_locations3
NCR_job['Company_names']= company_names3
NCR_job['Experience_required']= Experience_required3
NCR_job
# Out:
#                                            Job_Title  \
# 0  Data Scientist / Data Analyst / Business Analy...
# 1          Data Scientist/ Machine Learning Engineer
# 2                      Data Scientist / Data Analyst
# 3  Only Fresher / Data Scientist / Data Analyst /...
# 4  Data Scientist / Data Analyst / Business Analy...
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                         Data Scientist - Insurance
# 8               Data Scientist - WFH - MIND Infotech
# 9                 Junior Data Scientists & Engineers
#
#                                        Job_locations  \
# 0                  Ghaziabad, Faridabad, Delhi / NCR
# 1  Hyderabad/Secunderabad, Pune, Ahmedabad, Gurga...
# 2                                   Gurgaon/Gurugram
# 3               Noida, Gurgaon/Gurugram, Delhi / NCR
# 4                 Noida, New Delhi, Gurgaon/Gurugram
# 5                          Noida\n(WFH during Covid)
# ...

# %% [markdown]
# Q4: Write a python program to scrape data for first 10 job results for Data scientist Designation in Noida location. You have to scrape company_name, No. of days ago when job was posted, Rating of the company.

# %%
Driver4=webdriver.Chrome("chromedriver.exe")
url="https://www.glassdoor.co.in/index.htm/" 
Driver4.get(url)

# %%
search_job= Driver4.find_element_by_xpath('//input[@id="sc.keyword"]')
search_job.send_keys("Data Scientist")
search_loc=Driver4.find_element_by_xpath('//input[@id="sc.location"]')
search_loc.send_keys("Noida")
search_btn=Driver4.find_element_by_xpath('//button[@class="gd-ui-button ml-std col-auto search__SearchStyles__newSearchButton css-1dqvyh7"]')
search_btn.click()

# %%
company_name= Driver4.find_elements_by_xpath('//div[@class="d-flex justify-content-between align-items-start"]')

# %%
Company_name=[]
for i in company_name[0:10]:
    Company_name.append(i.text)

# %%
posted_time=Driver4.find_elements_by_xpath('//div[@class="d-flex align-items-end pl-std css-17n8uzw"]')

# %%
Posted_time=[]
for i in posted_time[0:10]:
    Posted_time.append(i.text)

# %%
company_rating=Driver4.find_elements_by_xpath('//span[@class=" job-search-key-srfzj0 e1cjmv6j0"]')
Company_rating=[]
for i in company_rating[0:10]:
    Company_rating.append(i.text)

# %%
GD_company=pd.DataFrame({})
GD_company['Company_name']= Company_name
GD_company['Posted_Time']=Posted_time
GD_company['Company_Rating']=Company_rating
GD_company
# Out:
#                              Company_name Posted_Time Company_Rating
# 0    Liberin Technologies Private Limited        30d+            3.9
# 1  AlgoScale Technologies Private Limited         19d            3.9
# 2                              Noisy Lion          4d            3.5
# 3                          Grail Insights          5d            3.6
# 4            Salasar New Age Technologies        30d+            3.5
# 5                                Lenskart          7d            4.1
# 6                                Techlive        30d+            3.8
# 7                          Grail Insights          5d            3.3
# 8                                Ericsson         12d            3.9
# 9                                 Genpact          7d            3.8

# %% [markdown]
# Q5: Write a python program to scrape the salary data for Data Scientist designation in Noida location.
# You have to scrape Company name, Number of salaries, Average salary, Min salary, Max Salary.

# %%
Driver4=webdriver.Chrome("chromedriver.exe")
url="https://www.glassdoor.co.in/Salaries/index.htm" 
Driver4.get(url)

# %%
search_job= Driver4.find_element_by_id('KeywordSearch')
search_job.send_keys("Data Scientist")

# %%
search_loc= Driver4.find_element_by_id('LocationSearch')
search_loc.send_keys("Noida")

# %%
search_btn= Driver4.find_element_by_xpath('//button[@class="gd-btn-mkt"]')

# %%
search_btn.click()

# %%
company_name=Driver4.find_elements_by_xpath('//a[@class="css-f3vw95 e1aj7ssy3"]')
Company_name=[]
for i in company_name[0:10]:
    Company_name.append(i.text)

# %%
min_salary=Driver4.find_elements_by_xpath('//div[@class="d-flex mt-xxsm css-79elbk epuxyqn0"]/p[1]')
Min_salary=[]
for i in min_salary[0:10]:
    Min_salary.append(i.text.replace('\n',''))
    
max_salary=Driver4.find_elements_by_xpath('//div[@class="d-flex mt-xxsm css-79elbk epuxyqn0"]/p[2]')
Max_salary=[]
for i in max_salary[0:10]:
    Max_salary.append(i.text.replace('\n',''))

# %%
average_salary=Driver4.find_elements_by_xpath('//div[@class="col-12 col-lg-4 px-lg-0 d-flex align-items-baseline"]')
Average_salary=[]
for i in average_salary[0:10]:
    Average_salary.append(i.text.replace('\n',''))

# %%
company_ratings=Driver4.find_elements_by_xpath('//span[@class="m-0 css-kyx745"]')
Company_ratings=[]
for i in company_ratings[0:10]:
    Company_ratings.append(i.text)

# %%
Salary_data=pd.DataFrame({})
Salary_data['Company_Name']= Company_name
Salary_data['Min_Salary']= Min_salary
Salary_data['Max_salary']= Max_salary
Salary_data['Average_Salary']= Average_salary
Salary_data['Company_Ratings']=Company_ratings
Salary_data
# Out:
#                 Company_Name Min_Salary Max_salary  Average_Salary  \
# 0  Tata Consultancy Services        ₹4L       ₹13L   ₹6,28,021 /yr
# 1                        IBM        ₹1L       ₹28L   ₹9,08,246 /yr
# 2                  Accenture        ₹6L       ₹23L  ₹11,93,390 /yr
# 3                  Delhivery        ₹5L       ₹1Cr  ₹12,49,716 /yr
# 4         Ericsson-Worldwide        ₹4L       ₹17L   ₹7,58,335 /yr
# 5         UnitedHealth Group        ₹8L       ₹16L  ₹12,80,000 /yr
# 6                      Optum        ₹8L       ₹20L  ₹12,70,000 /yr
# 7     Optum Global Solutions       ₹10L       ₹18L  ₹14,55,430 /yr
# 8         Valiance Solutions        ₹5L       ₹15L   ₹8,86,064 /yr
# 9                EXL Service        ₹6L       ₹16L  ₹11,10,000 /yr
#
#   Company_Ratings
# 0             3.9
# 1             3.9
# 2             4.1
# 3             3.7
# 4               4
# 5             3.7
# 6             3.7
# 7             3.9
# 8             4.2
# 9             3.6

# %% [markdown]
# Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# 4. Discount %

# %%
Driver=webdriver.Chrome("chromedriver.exe")
url="https://www.flipkart.com/" 
Driver.get(url)

# %%
search_product= Driver.find_element_by_xpath('//input[@class="_3704LK"]')
search_product.send_keys("sunglasses")

search_btn=Driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
search_btn.click()

# %%
page1=Driver.find_elements_by_xpath('//a[@class="ge-49M _2Kfbh8"]')

URl= Driver.find_elements_by_xpath('//a[@class="ge-49M"]')

# %%
urls=[]
for i in page1:
    urls.append(i.get_attribute('href'))
urls

for i in URl[0:2]:
    urls.append(i.get_attribute('href'))

# %%
Brand_name=[]
Product_Description=[]
Price=[]
Discount=[]

for i in urls:
    Brand=Driver.find_elements_by_xpath('//div[@class="_2WkVRV"]')
    for i in Brand:
        Brand_name.append(i.text)
    
    Product_Desc=Driver.find_elements_by_xpath('//a[@class="IRpwTa"]')
    for i in Product_Desc:
        Product_Description.append(i.text)
    
    price=Driver.find_elements_by_xpath('//div[@class="_30jeq3"]')
    for i in price:
        Price.append(i.text)

    price=Driver.find_elements_by_xpath('//div[@class="_30jeq3"]')
    for i in price:
        Price.append(i.text)  
    
    discount=Driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]')
    for i in discount:
        Discount.append(i.text)   
        

    discount=Driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]')
    for i in discount:
        Discount.append(i.text)

# %%
SunGlass=pd.DataFrame({})
SunGlass['Brand_name']=Brand_name[0:100]
SunGlass['Product_Description']=Product_Description[0:100]
SunGlass['Price']= Price[0:100]
SunGlass['Discount']=Discount[0:100]
SunGlass
# Out:
#            Brand_name                                Product_Description  \
# 0              GANSTA              UV Protection Aviator Sunglasses (57)
# 1              AISLIN  UV Protection, Gradient Wayfarer, Clubmaster S...
# 2   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 3           Elligator                UV Protection Round Sunglasses (54)
# 4      kingsunglasses  Mirrored, UV Protection Wayfarer Sunglasses (F...
# ..                ...                                                ...
# 95           Badfella  UV Protection, Mirrored Retro Square Sunglasse...
# 96             PIRASO              UV Protection Aviator Sunglasses (54)
# 97          ROYAL SON          UV Protection Rectangular Sunglasses (58)
# 98           Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 99              NuVew              UV Protection Aviator Sunglasses (57)
#
#    Price Discount
# 0   ₹284  85% off
# 1   ₹525  65% off
# 2   ₹198  88% off
# ...

# %% [markdown]
# Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.

# %%
driver = webdriver.Chrome('chromedriver.exe')
url= "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace"
driver.get(url)

# %%
page1=driver.find_elements_by_xpath('//a[@class="ge-49M _2Kfbh8"]')

URl= driver.find_elements_by_xpath('//a[@class="ge-49M"]')

# %%
urls=[]
for i in page1:
    urls.append(i.get_attribute('href'))
urls

for i in URl:
    urls.append(i.get_attribute('href'))

# %%
Rating=[]
Review_summary=[]
Full_review=[]

for i in urls:
    
    Ratings=driver.find_elements_by_xpath('//div[@class="_3LWZlK _1BLPMq"]')
    
    for i in Ratings:
        Rating.append(i.text)
        
    review_summary=driver.find_elements_by_xpath('//p[@class="_2-N8zT"]')
    
    for i in review_summary:
        Review_summary.append(i.text)
        
    full_review=driver.find_elements_by_xpath('//div[@class="t-ZTKy"]')
    
    for i in full_review:
        Full_review.append(i.text)

# %%
Phone_rating=pd.DataFrame({})
Phone_rating['Rating']=Rating
Phone_rating['Review_summary']=Review_summary
Phone_rating['Full_review']= Full_review
Phone_rating
# Out:
#    Rating       Review_summary  \
# 0       5            Brilliant
# 1       5       Simply awesome
# 2       5  Best in the market!
# 3       5     Perfect product!
# 4       5            Fabulous!
# ..    ...                  ...
# 95      5    Worth every penny
# 96      5        Great product
# 97      4          Good choice
# 98      5    Worth every penny
# 99      5   Highly recommended
#
#                                           Full_review
# 0   The Best Phone for the Money\n\nThe iPhone 11 ...
# 1   Really satisfied with the Product I received.....
# 2   Great iPhone very snappy experience as apple k...
# 3   Amazing phone with great cameras and better ba...
# 4   This is my first iOS phone. I am very happy wi...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 97  So far it’s been an AMAZING experience coming ...
# ...

# %% [markdown]
# Q8: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker :
# 1. Brand
# 2. Product Description
# 3. Price
# 4. discount %

# %%
Driver=webdriver.Chrome("chromedriver.exe")
url="https://www.flipkart.com/" 
Driver.get(url)

# %%
search_product= Driver.find_element_by_xpath('//input[@class="_3704LK"]')
search_product.send_keys("sneakers")

search_btn=Driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
search_btn.click()

# %%
page1=Driver.find_elements_by_xpath('//a[@class="ge-49M _2Kfbh8"]')

URl= Driver.find_elements_by_xpath('//a[@class="ge-49M"]')

# %%
urls=[]
for i in page1:
    urls.append(i.get_attribute('href'))
urls

for i in URl[0:2]:
    urls.append(i.get_attribute('href'))

# %%
Brand_name=[]
Product_Description=[]
Price=[]
Discount=[]

for i in urls:
    Driver.get(i)
    time.sleep(2)
    
    try:
        Brand=Driver.find_elements_by_xpath('//div[@class="_2WkVRV"]')
        for i in Brand:
            Brand_name.append(i.text)
    except:
        Brand_name.append('--')
    try:
        Product_Desc=Driver.find_elements_by_xpath('//a[@class="IRpwTa"]')
        for i in Product_Desc:
            Product_Description.append(i.text)
    except:
        Product_Description.append('--')
    try:
        price=Driver.find_elements_by_xpath('//div[@class="_30jeq3"]')   
        for i in price:
            Price.append(i.text)
    except:
        Price.append('--')
            
    try:
        discount=Driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]')
        for i in discount:
            Discount.append(i.text)
    except:
        Discount.append('--')

# %%
Shoes=pd.DataFrame({})
Shoes['Brand_name']=Brand_name[0:100]
Shoes['Product_Description']=Product_Description[0:100]
Shoes['Price']= Price[0:100]
Shoes['Discount']=Discount[0:100]
Shoes
# Out:
#    Brand_name                                Product_Description   Price  \
# 0      DUCATI                                   Sneakers For Men  ₹1,499
# 1       Echor  Mens Walking Running Shoes - Lightweight Breat...    ₹399
# 2    Magnolia                                   Sneakers For Men    ₹356
# 3      BRUTON  Combo Pack Of 4 Casual Shoes Loafer Shoes Snea...    ₹474
# 4    Longwalk                         Men Boxer Sneakers For Men    ₹236
# ..        ...                                                ...     ...
# 95  India hub                                   Sneakers For Men    ₹399
# 96  Englewood              Hip Hop Mid Perf IDP Sneakers For Men    ₹475
# 97        HOC                                   Sneakers For Men    ₹398
# 98    LuvShus                            Raptor Sneakers For Men    ₹449
# 99      Echor                                   Sneakers For Men    ₹429
#
#    Discount
# 0   59% off
# 1   60% off
# 2   64% off
# 3   86% off
# 4   52% off
# ...

# %% [markdown]
# Q9: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in the below image
# .
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image.
# Please

# %%
Driver= webdriver.Chrome("chromedriver.exe")
url="https://www.myntra.com/shoes" 
Driver.get(url)

# %%
Price_range=Driver.find_element_by_xpath('//input[@class="price-input" and @value="6897.0 TO 13595.0"]')
Price_range
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ff05793a5b04c0e43135d08b2a2285a5", element="71061d81-0dd3-4588-ac41-544f51990259")>

# %%
color_range=Driver.find_element_by_xpath('//span[@data-colorhex="black"]')
color_range.click()

# %%
Next_btn= Driver.find_element_by_xpath('//li[@class="pagination-next"]')

# %%
Brand=[]
Short_summary=[]
Price=[]

for i in range(1,3):
    
    brand=Driver.find_elements_by_xpath('//h3[@class="product-brand"]')
    for i in brand:
        Brand.append(i.text)
        
        
    short_summary=Driver.find_elements_by_xpath('//h4[@class="product-product"]')
    
    for i in short_summary:
        Short_summary.append(i.text)
        
    price=Driver.find_elements_by_xpath('//div[@class="product-price"]')
    
    for i in price:
        Price.append(i.text)
    
Next_btn.click()

# %%
Shoes_Data= pd.DataFrame({})
Shoes_Data['Brand']=Brand
Shoes_Data['Short_summary']= Short_summary
Shoes_Data['Price']=Price
Shoes_Data
# Out:
#                     Brand                         Short_summary  \
# 0                     H&M                           Women Mules
# 1                    Puma              Men Running Enzo 2 Shoes
# 2         PUMA Motorsport  Unisex Sf Drift Cat 5 Ultra Sneakers
# 3                    Nike          Men FLEX EXPERIENCE RN Shoes
# 4                 MENGLER                     Men Walking Shoes
# ..                    ...                                   ...
# 95                   Nike        Men Flex Run 2021 Running Shoe
# 96                   Puma        Men Cell Fraction Fade Running
# 97               Skechers               Women RUMBLE ON Sandals
# 98                   Nike           Men City Rep Training Shoes
# 99  HRX by Hrithik Roshan                    Men Chunky Sneaker
#
#                         Price
# 0   Rs. 1379Rs. 2299(40% OFF)
# 1   Rs. 2474Rs. 5499(55% OFF)
# 2   Rs. 3149Rs. 6999(55% OFF)
# 3                    Rs. 4995
# 4    Rs. 624Rs. 2499(75% OFF)
# ...

# %% [markdown]
# Q10: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:
# WEB SCRAPING ASSIGNMENT-2
# .
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. title
# 2. Ratings
# 3. Price

# %%
Driver= webdriver.Chrome("chromedriver.exe")
url="https://www.amazon.in/" 
Driver.get(url)

# %%
search_product= Driver.find_element_by_xpath('//input[@type="text"]')
search_product.send_keys("Laptop")

search_btn=Driver.find_element_by_xpath('//input[@id="nav-search-submit-button"]')
search_btn.click() 
filter_btn1=Driver.find_element_by_xpath('//li[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span')
filter_btn1.click()

filter_btn2=Driver.find_element_by_xpath('//li[@id="p_n_feature_thirteen_browse-bin/16757432031"]/span')
filter_btn2.click()

# %%
title=Driver.find_elements_by_xpath('//span[@class="a-size-medium a-color-base a-text-normal"]')
Title=[]
for i in title[0:10]:
    Title.append(i.text)
    
price=Driver.find_elements_by_xpath('//span[@class="a-price-whole"]')    
Price=[]
for i in price[0:10]:
    Price.append(i.text)

# %%
Url= Driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')

# %%
Lapi_urls=[]
for i in Url:
    Lapi_urls.append(i.get_attribute('href'))

# %%
Rating=[]
for i in Lapi_urls[0:10]:
    Driver.get(i)
    time.sleep(5)
    try:
        rating=Driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]')
        Rating.append(rating.text)
    except:
        Rating.append('--')

# %%
Laptop_data= pd.DataFrame({})
Laptop_data['Title']=Title
Laptop_data['Price']= Price
Laptop_data['Rating']= Rating
Laptop_data
# Out:
#                                                Title     Price        Rating
# 0  HP Envy 11th Gen Core i7 Processor 13.3-inch (...  1,23,350  4.1 out of 5
# 1  Acer Swift 5 14" (35.56cms) Full HD IPS Displa...    94,999  3.7 out of 5
# 2  Mi Notebook Horizon Edition 14 Intel Core i7-1...    57,990  4.2 out of 5
# 3  Lenovo IdeaPad S540 11th Gen Intel Core i7 13....    77,990  4.3 out of 5
# 4  Fujitsu UH-X 11th Gen Intel Core i7 13.3” (33....  1,07,990  4.1 out of 5
# 5  ASUS ROG G703GI-E5148T 17.3" (43.94 cms) FHD 1...  5,56,524  3.7 out of 5
# 6  ASUS TUF Dash F15 (2021), 15.6-inch (39.62 cms...    85,990            --
# 7  ASUS TUF Dash F15 (2021), 15.6-inch (39.62 cms...    84,990    3 out of 5
# 8  HP Pavilion 13(2021) 11th Gen Intel Core i7 La...    92,990    5 out of 5
# 9  Lenovo IdeaPad Flex 5 11th Gen Intel Core i7 1...    98,500  4.1 out of 5
